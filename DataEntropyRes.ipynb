# %%
from PIL import Image
import skimage.measure 
import numpy as np
# img = Image.open('KeyFra/imgs/10778.jpg')
# image = np.array(img)
# entropy = skimage.measure.shannon_entropy(image)
# entropy

# %%
import matplotlib.pyplot as plt
# plt.imshow(image, cmap='gray')

# %%
import os
from os import listdir
 
# get the path/directory
folder_dir = "Res/imgs/"
n = 0
sum = 0
i = 0
fr = []#creating an empty list named fr
for images in os.listdir(folder_dir):
    # check if the image ends with png
    if (images.endswith(".jpg")):
        n += 1
        print(images)
        img = Image.open(folder_dir+images)
        image = np.array(img)
#         plt.figure()
#         plt.imshow(image, cmap='gray')
        entropy = skimage.measure.shannon_entropy(image)
        print(entropy)
        sum += entropy
        i += 1
#         if entropy < 7.7:
#             i += 1
#             fr.append(images)
#     if n == 10:
#         break
# Out:
# 10778.jpg
# 7.104402985354597
# 10779.jpg
# 7.26301558225901
# 10780.jpg
# 7.611025698882344
# 10781.jpg
# 7.862379138272957
# 10782.jpg
# 7.863703690977609
# 10783.jpg
# 7.829281936986245
# 10784.jpg
# 7.810302589053003
# 10785.jpg
# 7.841629560769877
# 10786.jpg
# 7.8371840097047905
# 10787.jpg
# 7.837306614897341
# 10788.jpg
# 7.8211823054836405
# 10789.jpg
# 7.815448730543431
# 10792.jpg
# 7.705192151154706
# 10793.jpg
# 7.535087492759595
# 10794.jpg
# 7.396458863934779
# 10795.jpg
# 7.220448959474345
# 10798.jpg
# 7.674368330837447
# 10799.jpg
# 7.633546576819242
# 10801.jpg
# 7.659238130232295
# 10802.jpg
# 7.6713449383905585
# 10803.jpg
# 7.714343062350993
# 10804.jpg
# 7.736463097593066
# 10805.jpg
# 7.789195687111877
# 10806.jpg
# 7.805010812685419
# 10807.jpg
# 7.7815325528766826
# 10808.jpg
# 7.850605315579405
# 10809.jpg
# 7.821380763553877
# 10816.jpg
# 7.8373610198727315
# 10832.jpg
# 7.540461787192117
# 10833.jpg
# 7.317320511964254
# 10834.jpg
# 7.221208962057556
# ...

# %%
print(i)
print(sum/n)
print("Final:" , sum/n)
# Out:
# 4494
# 7.6452217958279025
# Final: 7.6452217958279025

# %%
# import shutil, os
# for f in fr:
#     shutil.copy(folder_dir + f, 'keyframesSimple2/images/')

# %%
# label_dir = 'data/labels/'
# import shutil, os
# for f in fr:
#     shutil.copy(label_dir + f.rsplit( ".", 1 )[ 0 ] + '_lab.png', 'keyframesSimple2/labels/')
